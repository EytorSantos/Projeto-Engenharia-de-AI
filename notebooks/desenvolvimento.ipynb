# %% [markdown]
# # MedAssist RAG - Desenvolvimento e Experimentos
#
# Este notebook documenta o processo de desenvolvimento do sistema MedAssist RAG, incluindo a análise exploratória das bulas e testes de recuperação de informação.

# %%
import os
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Caminho para as bulas
PASTA_BULAS = '../data/minhas_bulas'

# Carregamento das bulas
loader = DirectoryLoader(PASTA_BULAS, glob='**/*.md', loader_cls=TextLoader)
documentos = loader.load()
print(f'Total de bulas carregadas: {len(documentos)}')
